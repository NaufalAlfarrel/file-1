# %% [markdown]
# <a href="https://colab.research.google.com/github/NaufalAlfarrel/file-1/blob/main/Aol_No_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.polynomial import Polynomial
from sklearn.metrics import mean_squared_error, r2_score


production = [1863, 1614, 2570, 1685, 2101, 1811, 2457, 2171, 2134, 2502, 2358, 2399, 2048, 2523, 2086, 2391, 2150, 2340, 3129, 2277, 2964, 2997, 2747, 2862, 3405, 2677, 2749, 2755, 2963, 3161, 3623, 2768, 3141, 3439, 3601, 3531, 3477, 3376, 4027, 3175, 3274, 3334, 3964, 3649, 3502, 3688, 3657, 4422, 4197, 4441, 4736, 4521, 4485, 4644, 5036, 4876, 4789, 4544, 4975, 5211, 4880, 4933, 5079, 5339, 5232, 5520, 5714, 5260, 6110, 5334, 5988, 6235, 6365, 6266, 6345, 6118, 6497, 6278, 6638, 6590, 6271, 7246, 6584, 6594, 7092, 7326, 7409, 7976, 7959, 8012, 8195, 8008, 8313, 7791, 8368, 8933, 8756, 8613, 8705, 9098, 8769, 9544, 9050, 9186, 10012, 9685, 9966, 10048, 10244, 10740, 10318, 10393, 10986, 10635, 10731, 11749, 11849, 12123, 12274, 11666, 11960, 12629, 12915, 13051, 13387, 13309, 13732, 13162, 13644, 13808, 14101, 13992, 15191, 15018, 14917, 15046, 15556, 15893, 16388, 16782, 16716, 17033, 16896, 17689]

x = np.arange(len(production))
y = np.array(production)
p = Polynomial.fit(x, y, 4)

plt.figure(figsize=(10, 6))
plt.plot(x, y, marker='o', linestyle='-', label='Produksi Bulanan', color='blue')
plt.title('Produksi Tas Bulanan (Januari 2018 - Desember 2023)')
plt.xlabel('Bulan')
plt.ylabel('Produksi')
plt.grid(True)
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(x, y, marker='o', linestyle='-', label='Produksi Bulanan', color='blue')
plt.plot(x, p(x), label='Trend Produksi', color='red')
plt.title('Trend Produksi Tas Bulanan')
plt.xlabel('Bulan')
plt.ylabel('Produksi')
plt.grid(True)
plt.legend()
plt.show()

y_pred = p(x)
mse = np.sqrt(mean_squared_error(y, y_pred))
r2 = r2_score(y, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 282.41533427699954
# R-squared: 0.9957652336387167
